# %%
#Write a python program to replicate a Banking system. The following features are mandatory:
#1. Account login
#2. Amount Depositing
#3. Amount Withdrawal


import random

class Login:         #user login
    def __init__(self,n, p,amt):
        self.id =n
        self.password =p
        self.error = "Please enter a valid username and password"
        self.amt=amt
    def check(self):                      
        if (self.id== uid and self.password==pas):
            print("***Login successful***")
        
        else:
            print(self.error)
            
    
class Account: # after login display account details
    def __init__(self,name,r, amt):
        self.name =name
        self.r=r
        self.amt= amt
                        
    def show(self):
        print(f"\n WELCOME.. {self.name},\n\t Account Number : {self.r}\n\t Current balance: {self.amt}")
    
        
print("Create Bank Account\n\n")

name=input("Enter your name :") 
email=input("Enter your email id :")
amt=int(input("Enter your first deposit amount:")) 
r=random.randint(100,1000)        #auto generation of account number
n=print("your account number is : ",r)
p=input("Create password :")

#login 
print("\n\n ***your username is your account number\n\n")
print("\n----LOGIN-----\n")
uid = input("\tEnter your user name: ")
pas= input("\tEnter password: ")
log = Login(uid,pas,amt)
log.check()

# show account details after login
account1 = Account(name,r,amt)
account1.show()

#user option for transactions
print("\noptions:\n1.Deposite money\n2.Withdraw money")
op=int(input("\nchoose your option : "))
if op==1:           
    p=int(input("\nDeposite amount  :"))
    amt=p+amt
    print("\nBalance  :",amt)
elif op==2:
    p=int(input("\nWithdrawal amount :"))
    amt=p-amt
    print("\nBalance  :",amt)
else:
    print("invalid option")
# Out:
# Create Bank Account
#
#
# Enter your name :saranya
# Enter your email id :saranya@gmail.com
# Enter your first deposit amount:2000
# your account number is :  485
# Create password :saru
#
#
#  ***your username is your account number
#
#
#
# ----LOGIN-----
#
# 	Enter your user name: 485
# 	Enter password: saru
# ***Login successful***
#
#  WELCOME.. saranya,
# 	 Account Number : 485
# 	 Current balance: 2000
#
# options:
# 1.Deposite money
# 2.Withdraw money
#
# choose your option : 1
#
# Deposite amount  :1000
#
# Balance 3000
